# %% [markdown]
# # **Data Cleaning of NBA webscraping data Part[2 of 3] 🧹🫧**

# %% [markdown]
#    * In this notebook, we're diving headfirst into the exciting world of data cleaning. This is where we roll up our sleeves, grab our digital brooms 🧹, and get down to the nitty-gritty of making our data spotless.
#
#    * **Our mission?** To identify hidden patterns, unearth insights, and whip this dataset into shape. 📊💡 Because when it comes to machine learning, a clean dataset is your best friend.
#
#    * We'll be using a variety of functions, techniques, and **exploratory data analysis (EDA)** approaches to get the job done. So, buckle up for a data cleaning journey that'll leave your data squeaky clean and ready for the next step in our NBA data saga.

# %% [markdown]
# ## Loading Required Library 📚

# %%
#defining library
import pandas as pd
import matplotlib as plt

# %% [markdown]
# ## Data Loading & Cleaning

# %%
#loading the mvp data frame for cleaning

mvps= pd.read_csv('mvp.csv')
mvps.head()
# Out:
#    Unnamed: 0 Rank           Player  Age   Tm  First  Pts Won  Pts Max  Share  \
# 0           0    1   Michael Jordan   27  CHI   77.0    891.0      960  0.928
# 1           1    2    Magic Johnson   31  LAL   10.0    497.0      960  0.518
# 2           2    3   David Robinson   25  SAS    6.0    476.0      960  0.496
# 3           3    4  Charles Barkley   27  PHI    2.0    222.0      960  0.231
# 4           4    5      Karl Malone   27  UTA    0.0    142.0      960  0.148
#
#     G  ...   TRB   AST  STL  BLK    FG%    3P%    FT%    WS  WS/48  year
# 0  82  ...   6.0   5.5  2.7  1.0  0.539  0.312  0.851  20.3  0.321  1991
# 1  79  ...   7.0  12.5  1.3  0.2  0.477  0.320  0.906  15.4  0.251  1991
# 2  82  ...  13.0   2.5  1.5  3.9  0.552  0.143  0.762  17.0  0.264  1991
# 3  67  ...  10.1   4.2  1.6  0.5  0.570  0.284  0.722  13.4  0.258  1991
# 4  82  ...  11.8   3.3  1.1  1.0  0.527  0.286  0.770  15.5  0.225  1991
#
# [5 rows x 22 columns]

# %% [markdown]
# Choosing the appropriate column for the MVPs dataframe, which involves feature selection.

# %%
mvps=mvps[['Player', 'year', 'Pts Won', 'Pts Max', 'Share']]
mvps
# Out:
#               Player  year  Pts Won  Pts Max  Share
# 0     Michael Jordan  1991    891.0      960  0.928
# 1      Magic Johnson  1991    497.0      960  0.518
# 2     David Robinson  1991    476.0      960  0.496
# 3    Charles Barkley  1991    222.0      960  0.231
# 4        Karl Malone  1991    142.0      960  0.148
# ..               ...   ...      ...      ...    ...
# 494    Stephen Curry  2023      5.0     1000  0.005
# 495     Jimmy Butler  2023      3.0     1000  0.003
# 496     De'Aaron Fox  2023      2.0     1000  0.002
# 497    Jalen Brunson  2023      1.0     1000  0.001
# 498        Ja Morant  2023      1.0     1000  0.001
#
# [499 rows x 5 columns]

# %%
# loading the player dataframe to clean

players=pd.read_csv('playe.csv')
players.head()
# Out:
#    Unnamed: 0 Rk              Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0           0  1      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3  ...
# 1           1  2  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  ...
# 2           2  3          Mark Acres   C  28  ORL  68   0  19.3  1.6  ...
# 3           3  4       Michael Adams  PG  28  DEN  66  66  35.5  8.5  ...
# 4           4  5        Mark Aguirre  SF  31  DET  78  13  25.7  5.4  ...
#
#    ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS  year
# 0  0.6  1.4  2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1  0.5  1.3  1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2  2.1  3.2  5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3  0.9  3.0  3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4  1.7  3.1  4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
#
# [5 rows x 32 columns]

# %% [markdown]
# Removing unnecessary columns for machine learning

# %%
del players['Unnamed: 0']

# %%
del players['Rk']

# %%
players.head()
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 0      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7  .474  ...  0.6
# 1  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1  .413  ...  0.5
# 2          Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1  .509  ...  2.1
# 3       Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5  .394  ...  0.9
# 4        Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7  .462  ...  1.7
#
#    DRB  TRB   AST  STL  BLK  TOV   PF   PTS  year
# 0  1.4  2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1  1.3  1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2  3.2  5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3  3.0  3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4  3.1  4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
#
# [5 rows x 30 columns]

# %% [markdown]
# Identify the names to ensure they are in a proper structure with no extra special symbols.

# %%
players['Player'].head(50)
# Out:
# 0         Alaa Abdelnaby
# 1     Mahmoud Abdul-Rauf
# 2             Mark Acres
# 3          Michael Adams
# 4           Mark Aguirre
# 5            Danny Ainge
# 6            Mark Alarie
# 7           Steve Alford
# 8          Greg Anderson
# 9          Greg Anderson
# 10         Greg Anderson
# 11         Greg Anderson
# 12         Nick Anderson
# 13          Ron Anderson
# 14       Willie Anderson
# 15        Michael Ansley
# 16        B.J. Armstrong
# 17         Vincent Askew
# 18          Keith Askins
# 19           Miloš Babić
# 20          Thurl Bailey
# 21           Cedric Ball
# 22         Ken Bannister
# 23      Charles Barkley*
# 24           Dana Barros
# 25           John Battle
# 26          Kenny Battle
# 27          Kenny Battle
# 28          Kenny Battle
# 29       William Bedford
# 30       Benoit Benjamin
# 31       Benoit Benjamin
# 32       Benoit Benjamin
# 33       Winston Bennett
# 34           Larry Bird*
# 35      Rolando Blackman
# 36          Lance Blanks
# ...

# %% [markdown]
# In the list of names above, names like 'Larry Bird*' and 'Charles Barkley*' contain special symbols '*' that need to be cleaned.

# %%
players['Player']=players['Player'].str.replace("*", "", regex=False)

# %%
players.head(50)
# Out:
#                 Player    Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 0       Alaa Abdelnaby     PF   22  POR  43   0   6.7  1.3   2.7   .474  ...
# 1   Mahmoud Abdul-Rauf     PG   21  DEN  67  19  22.5  6.2  15.1   .413  ...
# 2           Mark Acres      C   28  ORL  68   0  19.3  1.6   3.1   .509  ...
# 3        Michael Adams     PG   28  DEN  66  66  35.5  8.5  21.5   .394  ...
# 4         Mark Aguirre     SF   31  DET  78  13  25.7  5.4  11.7   .462  ...
# 5          Danny Ainge     SG   31  POR  80   0  21.4  4.2   8.9   .472  ...
# 6          Mark Alarie     PF   27  WSB  42   1  14.0  2.4   5.4   .440  ...
# 7         Steve Alford     PG   26  DAL  34   0   6.9  1.7   3.4   .504  ...
# 8        Greg Anderson     PF   26  TOT  68   2  13.6  1.7   4.0   .430  ...
# 9        Greg Anderson     PF   26  MIL  26   0   9.5  1.0   2.8   .370  ...
# 10       Greg Anderson     PF   26  NJN   1   0  18.0  4.0   4.0  1.000  ...
# ...

# %%
def single_row(df):
    if df.shape[0] == 1:
        return df
    else:
        row=df[df['Tm']=='TOT']
        row['Tm']=df.iloc[-1, :]['Tm']
        return row
    
players = players.groupby(['Player', 'year']).apply(single_row)

# %%
players.head(20)
# Out:
#                                  Player Pos Age   Tm   G  GS    MP   FG   FGA  \
# Player        year
# A.C. Green    1991 164       A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6
#               1992 633       A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8
#               1993 1092      A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6
#               1994 1579      A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3
#               1995 2067      A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5
#               1996 2563      A.C. Green  SF  32  PHO  82  36  25.8  2.6   5.4
#               1997 3138      A.C. Green  PF  33  DAL  83  73  30.0  2.8   5.8
#               1998 3725      A.C. Green  PF  34  DAL  82  68  32.3  3.0   6.5
#               1999 4283      A.C. Green  PF  35  DAL  50  35  18.5  2.2   5.1
#               2000 4811      A.C. Green  PF  36  LAL  82  82  23.5  2.1   4.7
#               2001 5330      A.C. Green  PF  37  MIA  82   1  17.2  1.8   4.0
# ...

# %%
players.index=players.index.droplevel()

# %%
players.index=players.index.droplevel()

# %%
players.head()
# Out:
#           Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  DRB  \
# 164   A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  2.5  3.8
# 633   A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  3.7  5.6
# 1092  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  3.5  5.2
# 1579  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  3.4  5.8
# 2067  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  2.4  5.8
#
#       TRB  AST  STL  BLK  TOV   PF   PTS  year
# 164   6.3  0.9  0.7  0.3  1.2  1.4   9.1  1991
# 633   9.3  1.4  1.1  0.4  1.4  1.7  13.6  1992
# 1092  8.7  1.4  1.1  0.5  1.4  1.8  12.8  1993
# 1579  9.2  1.7  0.9  0.5  1.2  1.7  14.7  1994
# 2067  8.2  1.5  0.7  0.4  1.4  1.8  11.2  1995
#
# [5 rows x 30 columns]

# %% [markdown]
# Combining the two dataframes into a single dataframe to facilitate future machine learning purposes.

# %%
combined = players.merge(mvps, how="outer", on=['Player', 'year'])

# %%
combined.head(10)
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  AST  STL  BLK  \
# 0  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.9  0.7  0.3
# 1  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.4  1.1  0.4
# 2  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.4  1.1  0.5
# 3  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  1.7  0.9  0.5
# 4  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  1.5  0.7  0.4
# 5  A.C. Green  SF  32  PHO  82  36  25.8  2.6   5.4  .484  ...  0.9  0.5  0.3
# 6  A.C. Green  PF  33  DAL  83  73  30.0  2.8   5.8  .483  ...  0.8  0.8  0.2
# 7  A.C. Green  PF  34  DAL  82  68  32.3  3.0   6.5  .453  ...  1.5  1.0  0.3
# 8  A.C. Green  PF  35  DAL  50  35  18.5  2.2   5.1  .422  ...  0.5  0.6  0.2
# 9  A.C. Green  PF  36  LAL  82  82  23.5  2.1   4.7  .447  ...  1.0  0.6  0.2
#
#    TOV   PF   PTS  year Pts Won Pts Max Share
# 0  1.2  1.4   9.1  1991     NaN     NaN   NaN
# ...

# %%
combined[combined['Pts Won'] > 0]
# Out:
#               Player    Pos Age   Tm   G  GS    MP    FG   FGA   FG%  ...  \
# 206     Al Jefferson      C  29  CHA  73  73  35.0   9.6  18.8  .509  ...
# 360    Allen Iverson     PG  21  PHI  76  74  40.1   8.2  19.8  .416  ...
# 362    Allen Iverson     SG  23  PHI  48  48  41.5   9.1  22.0  .412  ...
# 363    Allen Iverson     SG  24  PHI  70  70  40.8  10.4  24.8  .421  ...
# 364    Allen Iverson     SG  25  PHI  71  71  42.0  10.7  25.5  .420  ...
# ...              ...    ...  ..  ...  ..  ..   ...   ...   ...   ...  ...
# 14689   Vince Carter     SF  23  TOR  82  82  38.1   9.6  20.7  .465  ...
# 14690   Vince Carter     SF  24  TOR  75  75  39.7  10.2  22.1  .460  ...
# 14694   Vince Carter  SF-SG  28  NJN  77  76  36.7   9.0  20.0  .452  ...
# 15082       Yao Ming      C  23  HOU  82  82  32.8   6.5  12.5  .522  ...
# 15087       Yao Ming      C  28  HOU  77  77  33.6   7.4  13.4  .548  ...
#
#        AST  STL  BLK  TOV   PF   PTS  year Pts Won Pts Max  Share
# ...

# %% [markdown]
# To identify if there are any null values and replace them with 0

# %%
combined[['Pts Won', 'Pts Max', 'Share']] = combined[['Pts Won', 'Pts Max', 'Share']].fillna(0)

# %%
combined[combined['Pts Won'] > 0]
# Out:
#               Player    Pos Age   Tm   G  GS    MP    FG   FGA   FG%  ...  \
# 206     Al Jefferson      C  29  CHA  73  73  35.0   9.6  18.8  .509  ...
# 360    Allen Iverson     PG  21  PHI  76  74  40.1   8.2  19.8  .416  ...
# 362    Allen Iverson     SG  23  PHI  48  48  41.5   9.1  22.0  .412  ...
# 363    Allen Iverson     SG  24  PHI  70  70  40.8  10.4  24.8  .421  ...
# 364    Allen Iverson     SG  25  PHI  71  71  42.0  10.7  25.5  .420  ...
# ...              ...    ...  ..  ...  ..  ..   ...   ...   ...   ...  ...
# 14689   Vince Carter     SF  23  TOR  82  82  38.1   9.6  20.7  .465  ...
# 14690   Vince Carter     SF  24  TOR  75  75  39.7  10.2  22.1  .460  ...
# 14694   Vince Carter  SF-SG  28  NJN  77  76  36.7   9.0  20.0  .452  ...
# 15082       Yao Ming      C  23  HOU  82  82  32.8   6.5  12.5  .522  ...
# 15087       Yao Ming      C  28  HOU  77  77  33.6   7.4  13.4  .548  ...
#
#        AST  STL  BLK  TOV   PF   PTS  year Pts Won Pts Max  Share
# ...

# %%
combined.head()
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  AST  STL  BLK  \
# 0  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.9  0.7  0.3
# 1  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.4  1.1  0.4
# 2  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.4  1.1  0.5
# 3  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  1.7  0.9  0.5
# 4  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  1.5  0.7  0.4
#
#    TOV   PF   PTS  year Pts Won Pts Max Share
# 0  1.2  1.4   9.1  1991     0.0     0.0   0.0
# 1  1.4  1.7  13.6  1992     0.0     0.0   0.0
# 2  1.4  1.8  12.8  1993     0.0     0.0   0.0
# 3  1.2  1.7  14.7  1994     0.0     0.0   0.0
# 4  1.4  1.8  11.2  1995     0.0     0.0   0.0
#
# [5 rows x 33 columns]

# %%
# loading the teams dataframe

team=pd.read_csv('teams_d.csv')

team.head(20)

# %%
team=team[~team['W'].str.contains('Division')]
team.head(20)
# Out:
#     Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G     SRS  year  \
# 0            0  56  26  .683     —  111.5  105.7    5.22  1991
# 1            1  44  38  .537  12.0  105.4  105.6   -0.39  1991
# 2            2  39  43  .476  17.0  103.1  103.3   -0.43  1991
# 3            3  30  52  .366  26.0  101.4  106.4   -4.84  1991
# 4            4  26  56  .317  30.0  102.9  107.5   -4.53  1991
# 5            5  24  58  .293  32.0  101.8  107.8   -5.91  1991
# 7            7  61  21  .744     —  110.0  101.0    8.57  1991
# 8            8  50  32  .610  11.0  100.1   96.8    3.08  1991
# 9            9  48  34  .585  13.0  106.4  104.0    2.33  1991
# 10          10  43  39  .524  18.0  109.8  109.0    0.72  1991
# 11          11  41  41  .500  20.0  111.7  112.1   -0.37  1991
# 12          12  33  49  .402  28.0  101.7  104.2   -2.33  1991
# 13          13  26  56  .317  35.0  102.8  108.0   -4.95  1991
# 15           1  55  27  .671     —  107.1  102.6    4.30  1991
# ...

# %%
team['Team']=team['Team'].str.replace('*','', regex=False)
team.head()
# Out:
#    Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G    SRS  year  \
# 0           0  56  26  .683     —  111.5  105.7   5.22  1991
# 1           1  44  38  .537  12.0  105.4  105.6  -0.39  1991
# 2           2  39  43  .476  17.0  103.1  103.3  -0.43  1991
# 3           3  30  52  .366  26.0  101.4  106.4  -4.84  1991
# 4           4  26  56  .317  30.0  102.9  107.5  -4.53  1991
#
#                  Team
# 0      Boston Celtics
# 1  Philadelphia 76ers
# 2     New York Knicks
# 3  Washington Bullets
# 4     New Jersey Nets

# %% [markdown]
# Loading the 'nickname.txt' file for team name correction, which is particularly helpful when joining the dataframes with each other.

# %%
nick = pd.read_csv('nicknames.txt', sep=',')
nick.to_csv('nickname.csv')

# %%
nicknames={}

with open('nickname.csv', 'r', encoding='utf-8') as f:
    lines = f.readlines()
    for line in lines[1:]:
        values = line.replace("\n", "").split(",")
        if len(values) >= 2:
            abr, name = values[1], values[2]
            nicknames[abr] = name
        else:
            # Handle lines with fewer values or empty lines
            print(f"Skipping line: {line}")

# %%
combined['Team']=combined['Tm'].map(nicknames)
combined.head()
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  STL  BLK  TOV  \
# 0  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.7  0.3  1.2
# 1  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.1  0.4  1.4
# 2  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.1  0.5  1.4
# 3  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  0.9  0.5  1.2
# 4  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  0.7  0.4  1.4
#
#     PF   PTS  year Pts Won Pts Max Share                Team
# 0  1.4   9.1  1991     0.0     0.0   0.0  Los Angeles Lakers
# 1  1.7  13.6  1992     0.0     0.0   0.0  Los Angeles Lakers
# 2  1.8  12.8  1993     0.0     0.0   0.0  Los Angeles Lakers
# 3  1.7  14.7  1994     0.0     0.0   0.0        Phoenix Suns
# 4  1.8  11.2  1995     0.0     0.0   0.0        Phoenix Suns
#
# [5 rows x 34 columns]

# %%
stats=combined.merge(team, how='outer', on=['Team','year'])
stats.shape
# Out:
# (15236, 42)

# %%
combined.shape
# Out:
# (15236, 34)

# %%
del stats['Unnamed: 0']

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age         object
# Tm          object
# G           object
# GS          object
# MP          object
# FG          object
# FGA         object
# FG%         object
# 3P          object
# 3PA         object
# 3P%         object
# 2P          object
# 2PA         object
# 2P%         object
# eFG%        object
# FT          object
# FTA         object
# FT%         object
# ORB         object
# DRB         object
# TRB         object
# AST         object
# STL         object
# BLK         object
# TOV         object
# PF          object
# PTS         object
# year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W           object
# L           object
# W/L%        object
# GB          object
# PS/G        object
# PA/G        object
# SRS         object
# dtype: object

# %%
stats=stats.apply(pd.to_numeric, errors='ignore')
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age          int64
# Tm          object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W            int64
# L            int64
# W/L%       float64
# GB          object
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
stats['GB'].unique()
# Out:
# array(['5.0', '14.0', '23.0', '7.0', '—', '40.0', '42.0', '18.0', '6.0',
#        '24.0', '26.0', '37.0', '29.0', '21.0', '28.0', '13.0', '25.0',
#        '8.0', '19.0', '3.0', '1.0', '17.0', '15.0', '9.0', '2.0', '35.0',
#        '20.0', '11.0', '16.0', '41.0', '12.0', '50.0', '10.0', '30.0',
#        '34.0', '4.0', '1.5', '22.0', '51.0', '36.0', '43.0', '39.0',
#        '18.5', '31.0', '48.0', '46.0', '10.5', '32.0', '38.0', '27.0',
#        '33.0', '21.5', '45.0', '22.5', '25.5', '3.5', '20.5', '11.5',
#        '44.0', '52.0', '56.0', '2.5', '12.5', '47.0', '32.5', '4.5'],
#       dtype=object)

# %%
stats['GB']=stats['GB'].str.replace('—','0')
stats['GB'].unique()
# Out:
# array(['5.0', '14.0', '23.0', '7.0', '0', '40.0', '42.0', '18.0', '6.0',
#        '24.0', '26.0', '37.0', '29.0', '21.0', '28.0', '13.0', '25.0',
#        '8.0', '19.0', '3.0', '1.0', '17.0', '15.0', '9.0', '2.0', '35.0',
#        '20.0', '11.0', '16.0', '41.0', '12.0', '50.0', '10.0', '30.0',
#        '34.0', '4.0', '1.5', '22.0', '51.0', '36.0', '43.0', '39.0',
#        '18.5', '31.0', '48.0', '46.0', '10.5', '32.0', '38.0', '27.0',
#        '33.0', '21.5', '45.0', '22.5', '25.5', '3.5', '20.5', '11.5',
#        '44.0', '52.0', '56.0', '2.5', '12.5', '47.0', '32.5', '4.5'],
#       dtype=object)

# %%
stats['GB']=pd.to_numeric(stats['GB'])
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age          int64
# Tm          object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W            int64
# L            int64
# W/L%       float64
# GB         float64
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
stats.to_csv('player_mvp_stats.csv')

# %%
high_score=stats[stats['G'] > 70].sort_values('PTS', ascending=False).head(10)
high_score.plot.bar('Player','PTS')
# Out:
# <AxesSubplot:xlabel='Player'>

# %%
high_pts_year=stats.groupby('year').apply(lambda x: x.sort_values('PTS', ascending=False).head(1))
high_pts_year.plot.bar("year", "PTS")
# Out:
# <AxesSubplot:xlabel='year'>

# %%
stats.corr()['Share'].plot.bar()
# Out:
# <AxesSubplot:>
